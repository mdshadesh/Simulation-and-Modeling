# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("My dataset.csv")

# %%
data
# Out:
#     area    price
# 0    850    52000
# 1    900    75000
# 2   1000    91000
# 3   1050   150000
# 4   1100   170000
# 5   1150   175000
# 6   1200   190000
# 7   1250   205000
# 8   1300   250600
# 9   1340   390000
# 10  1380   450000
# 11  1400   502650
# 12  1450   550200
# 13  1500   592580
# 14  1550   750000
# 15  1600   850000
# 16  1650   900000
# 17  1700  1000000
# 18   500    25860
# 19   600   600000

# %%
data.head(15)
# Out:
#     area   price
# 0    850   52000
# 1    900   75000
# 2   1000   91000
# 3   1050  150000
# 4   1100  170000
# 5   1150  175000
# 6   1200  190000
# 7   1250  205000
# 8   1300  250600
# 9   1340  390000
# 10  1380  450000
# 11  1400  502650
# 12  1450  550200
# 13  1500  592580
# 14  1550  750000

# %%
data.head(20)
# Out:
#     area    price
# 0    850    52000
# 1    900    75000
# 2   1000    91000
# 3   1050   150000
# 4   1100   170000
# 5   1150   175000
# 6   1200   190000
# 7   1250   205000
# 8   1300   250600
# 9   1340   390000
# 10  1380   450000
# 11  1400   502650
# 12  1450   550200
# 13  1500   592580
# 14  1550   750000
# 15  1600   850000
# 16  1650   900000
# 17  1700  1000000
# 18   500    25860
# 19   600   600000

# %%
data.isnull()
# Out:
#      area  price
# 0   False  False
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
# 5   False  False
# 6   False  False
# 7   False  False
# 8   False  False
# 9   False  False
# 10  False  False
# 11  False  False
# 12  False  False
# 13  False  False
# 14  False  False
# 15  False  False
# 16  False  False
# 17  False  False
# 18  False  False
# 19  False  False

# %%
data.shape
# Out:
# (20, 2)

# %%
data.isnull().any()
# Out:
# area     False
# price    False
# dtype: bool

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['area'],data['price'])
plt.xlabel('This is the Value of Area')
plt.ylabel('This is the Price value')
plt.title('Plotting the dataset')
# Out:
# Text(0.5, 1.0, 'Plotting the dataset')
